# %% [markdown]
# # Assignment 1
#
# Let's go back to our library program. You can use your solution to last weeks homework as starter code and build on it. Here is what the program should be able to do:
#
# From the previous assignment:
#
# - check out books from the library.
# - each book can be checked out only once
# - books can be returned to the library
# - the program keeps track of who checked out a book
#
# For this assignment add the following features:
#
# - if a book is not in the library, users should be able to request them to be bought
# - users can also donate books to the library
# - the library also stores the authors of books and users can query for those (e.g. enter a title and the program returns the authors)
#
# Use functions to structure your code.
#
# There are many ways to write this program. It is up to you how you structure interaction with it (e.g. first ask for what a user wants to do, then ask for specific inputs or try to capture all cases with one input process).

# %%
# your code
dictBorrowRecords = { "Alice in wonderland" : "Available", "Sociobiology":1,"Hitchhiker's guide to the galaxy": "Dustin Martin", "Romeo and Juliet": "Available","The Descent of man":"Coral Andrew"}
dictTitleAuthorRecords = { "Alice in wonderland" : "Lewis Carroll","Hitchhiker's guide to the galaxy": " Douglas Adams", "Romeo and Juliet": "William Shakespeare","The Descent of man":"Charles Darwin"}


def borrow(dictBorrowRecords,dictTitleAuthorRecords):
    a = input("Press 1 to borrow a book; Press 2 to return a book; Press 3 to donate a book")
    if int(a) == 2:
        a = input("What is your book's title?")
        dictBorrowRecords[a]="Available"
        
    elif int(a) == 3:
        a = input("What is your book's title?")
        b = input("What is the author of your book?")
        dictBorrowRecords[a]="Available"
        dictTitleAuthorRecords[a]=b
    else:
        a = input("Press 1 to use authors' name to search book; Press 2 to use title to search book")
        if int(a) == 2:
            a = input("What is your book's title?") 
            if a not in dictTitleAuthorRecords:
                print("This book is not in the library.")
                b = input("Do you want to make a request to buy it? Press 1 to requset, press 0 to exit")
                if int(b) == 1:
                    if a not in dictBorrowRecords:
                        dictBorrowRecords[str(a)]= 1
                    else:
                        dictBorrowRecords[str(a)]= int(dictBorrowRecords[str(a)]) + 1
                else:
                    return dictBorrowRecords

            elif dictBorrowRecords[a] != "Available":
                print("Sorry, this book has been checked out.")
                y = input("Press 1 to see all the books that a particular user has checked out; Press 2 to see the user who has checked out a book")
                if y == str(1):
                    print([k for k,v in dictBorrowRecords.items() if v != 0 or v != 1])
                if y == str(2):
                    print([v for v,v in dictBorrowRecords.items() if v != 0 or v != 1])
            else:
                print("This book is successfully checked out.")
                x=input("What is your name?")
                dictBorrowRecords[str(a)]=str(x)
                print(dictBorrowRecords)
        elif int(a) == 1:
            a = input("What is the authors' name of your book?") 
            if a not in dictTitleAuthorRecords.values():
                print("This book is not in the library.")
                b = input("Do you want to make a request to buy it? Press 1 to requset, press 0 to exit")
                if int(b) == 1:
                    c = input("What is your book's title?")
                    if c not in dictBorrowRecords:
                        dictBorrowRecords[c]= dictBorrowRecords[c]+ 1
                    else:
                        dictBorrowRecords[c]= 1
                else:
                    return dictBorrowRecords

            elif dictBorrowRecords[str([k for k,v in dictTitleAuthorRecords.items() if v == a][0])] != "Available":
                print("Sorry, this book has been checked out.")
                y = input("Press 1 to see all the books that a particular user has checked out; Press 2 to see the user who has checked out a book")
                if y == str(1):
                    print([k for k,v in dictBorrowRecords.items() if v != "Available" or v != 1])
                if y == str(2):
                    print([v for v,v in dictBorrowRecords.items() if v != 0 or v != 1])
            else:
                print("This book is successfully checked out.")
                x=input("What is your name?")
                dictBorrowRecords[str([k for k,v in dictTitleAuthorRecords.items() if v == a][0])]=str(x)
                print(dictBorrowRecords) 

borrow(dictBorrowRecords,dictTitleAuthorRecords)       

print(dictBorrowRecords)
print(dictTitleAuthorRecords)

# %% [markdown]
# # Assignment 2
#
# **This assignment should be submitted as standalone Python script.** Please put the code for this assignment in a dedicated file (not into this notebook) and run it from the command line. Add, commit, and push that file to your homework branch of your GitHub repo.
#
# Start out by creating a virtual environment. Activate it. Then install example-lfuncs into it.
#
# How create a Python file and put your code into it. Create a string variable that holds the first paragraph of a Wikipedia article of your choice. Now, turn that string into a list of words (you can use the string method `split()` to split the string at for example blanks.
#
# Now, create a loop that asks the user for what he wants to do. Give them the following options:
#
# * Find all the words that start with a specific prefix. The user can enter a prefix and the program finds all the words in the paragraph that start with that prefix and prints them.
#
# * Let the program count how often each words appears in the paragraph.
#
# Each option should be in its own function that you call from the main loop. The user should enter "exit" to end the program.

# %%
# no code here, put it into a Python script
